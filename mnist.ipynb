# %%
import tensorflow as tf

# %%
(train_features,train_target),(testing_features,testing_target)=tf.keras.datasets.fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
train_features.shape
# Out:
# (60000, 28, 28)

# %% [raw]
# testing_features.shape

# %%
testing_features.shape
# Out:
# (10000, 28, 28)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(train_features[0])

# %%
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(train_features[i])
plt.show()

# %% [raw]
# \

# %%
train_target.shape
# Out:
# (60000,)

# %% [markdown]
# testing_target.shape

# %%
from keras.utils import to_categorical

# %%
train_target=to_categorical(train_target)

# %%
train_target.shape
# Out:
# (60000, 10)

# %%
import keras
from keras.layers import Dense,Flatten
from keras.models import Sequential

# %%
model=Sequential()
model.add(Flatten(input_shape=(28,28)))
model.add(Dense(128,activation="relu"))
model.add(Dense(10,activation="softmax"))

# %% [markdown]
# # compile the model

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %% [markdown]
# # FIT TO THE MODEL

# %%
model.fit(train_features,train_target,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 11.5934 - accuracy: 0.6830
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.7282 - accuracy: 0.7407
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5734 - accuracy: 0.8001
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5251 - accuracy: 0.8119
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5202 - accuracy: 0.8147
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.5087 - accuracy: 0.8227
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4843 - accuracy: 0.8283
# Epoch 8/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.4780 - accuracy: 0.8339
# Epoch 9/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.4739 - accuracy: 0.8350
# Epoch 10/10
# ...

# %% [markdown]
# # predicting from model

# %%
plt.imshow(testing_features[0])

# %%
predictions=model.predict(testing_features)

# %%
predictions[0]
# Out:
# array([6.8789239e-23, 1.9924710e-24, 0.0000000e+00, 4.3239753e-16,
#        2.7225428e-32, 6.1866706e-03, 0.0000000e+00, 1.8218840e-02,
#        6.7925949e-13, 9.7559446e-01], dtype=float32)
